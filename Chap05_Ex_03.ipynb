# %% [markdown]
# <a href="https://colab.research.google.com/github/HISATAKA-KATO/EU_M_Math-Repository/blob/main/Chap05_Ex_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#今回利用するライブラリ
import numpy as np
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame
import numpy.random as random

#可視化ライブラリ
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set_style()
# %matplotlib inline

#小数点第三位まで表示
# %precision 3

#ランダムシード
np.random.seed(0)

#zipダウンロードライブラリ
import requests, zipfile
from io import StringIO
import io

# %%
# データの準備
x_array = np.array([1, 2, 3, 4, 5])
y_array = np.array([6, 7, 8, 9, 10])

# 条件：3番目(index 2)と4番目(index 3)はx_array、他はy_array

# ブール配列を作成
condition = np.array([False, False, True, True, False])

# np.where(condition, x, y)
result = np.where(condition, x_array, y_array)

print("x_array:", x_array)
print("y_array:", y_array)
print("結果:", result)
# Out:
# x_array: [1 2 3 4 5]
# y_array: [ 6  7  8  9 10]
# 結果: [ 6  7  3  4 10]
