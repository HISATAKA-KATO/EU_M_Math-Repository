# %% [markdown]
# <a href="https://colab.research.google.com/github/HISATAKA-KATO/EU_M_Math-Repository/blob/main/Chap05_Ex_011.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#今回利用するライブラリ
import numpy as np
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame
import numpy.random as random
from scipy import interpolate

#可視化ライブラリ
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set_style()
# %matplotlib inline

#小数点第三位まで表示
# %precision 3

#ランダムシード
np.random.seed(0)

#zipダウンロードライブラリ
import requests, zipfile
from io import StringIO
import io

# %%
#データ
x = np.linspace(0,10,num = 11,endpoint = True)
y = np.sin(x**2/5.0)
xnew = np.linspace(0,10,num = 30,endpoint = True)
#線形補間
f1 = interpolate.interp1d(x,y,'linear')
#スプライン補間
f2 = interpolate.interp1d(x,y,'quadratic')
#グラフ描画
plt.plot(x,y,'o',xnew,f1(xnew),'-',xnew,f2(xnew),'--')
plt.grid(True)
