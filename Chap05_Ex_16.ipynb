# %% [markdown]
# <a href="https://colab.research.google.com/github/HISATAKA-KATO/EU_M_Math-Repository/blob/main/Chap05_Ex_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#今回利用するライブラリ
import numpy as np
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame
import numpy.random as random
from scipy import interpolate
#積分
from scipy import integrate
from numpy import cos
import math

#可視化ライブラリ
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set_style()
# %matplotlib inline

#小数点第三位まで表示
# %precision 3

#ランダムシード
np.random.seed(0)

#zipダウンロードライブラリ
import requests, zipfile
from io import StringIO
import io

# %%
def calcCos(x):
  return np.cos(x)

# np.cosを使用して0からπまで積分
result = integrate.quad(np.cos, 0, math.pi)
print(result)
# Out:
# (4.9225526349740854e-17, 2.2102239425853306e-14)
