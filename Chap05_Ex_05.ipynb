# %% [markdown]
# <a href="https://colab.research.google.com/github/HISATAKA-KATO/EU_M_Math-Repository/blob/main/Chap05_Ex_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#今回利用するライブラリ
import numpy as np
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame
import numpy.random as random

#可視化ライブラリ
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set_style()
# %matplotlib inline

#小数点第三位まで表示
# %precision 3

#ランダムシード
np.random.seed(0)

#zipダウンロードライブラリ
import requests, zipfile
from io import StringIO
import io

# %%
sample_multi_array_data2 = np.arange(16).reshape(4,4)
sample_multi_array_data2

print('最小値：',sample_multi_array_data2.min())
print('最大値：',sample_multi_array_data2.max())
print('合計：',sample_multi_array_data2.sum())
print('平均：',sample_multi_array_data2.mean())
# Out:
# 最小値： 0
# 最大値： 15
# 合計： 120
# 平均： 7.5
